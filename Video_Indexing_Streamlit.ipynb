# %%
# !pip install -q streamlit
! pip install scenedetect[opencv]
! pip install ffmpeg-python
! pip install SpeechRecognition
! pip install langchain
! pip install transformers
! pip install accelerate
# !pip install googletrans==3.1.0a0
# !pip install googletrans --upgrade
# !pip install googletrans==3.1.0a0
# !pip install googletrans --upgrade
! pip install stanza
! pip install pydub SpeechRecognition

# %%
from huggingface_hub import login
login('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')
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# %cd /content/drive/MyDrive/video_seg
# Out:
# /content/drive/MyDrive/video_seg

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.72.186.255

# %%
# !streamlit run Generative_Video_Indexing_Streamlit.py & npx localtunnel --port 8501
# Out:
# [..................] / rollbackFailedOptional: verb npm-session c611f6aac6fa2c8
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.72.186.255:8501
#
# npx: installed 22 in 3.095s
# your url is: https://angry-paths-nail.loca.lt
